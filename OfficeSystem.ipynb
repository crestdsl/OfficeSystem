# %%
import sys
sys.path.append('../')

# %%
# importnb allows us to load the code from other notebooks
from importnb import Notebook
with Notebook():
    import OfficeAutomation.structure as structure
    import OfficeAutomation.environment as env
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.761s
#
# OK
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 32.691s
#
# OK
# E
# ======================================================================
# ERROR: test_presence_produces_correct_lighting_setting (OfficeAutomation.structure.FloorTest) (hw_presence='no presence', o1_presence='no presence', o2_presence='no presence', o3_presence='no presence', expected_hallway='off', expected_office1='off', expected_office2='off', expected_office3='off')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "../OfficeAutomation/structure.ipynb", line 1065, in test_presence_produces_correct_lighting_setting
#   File "../crestdsl/simulation/simulator.py", line 45, in stabilise
#     return self.advance_and_stabilise_system(0)
#   File "../crestdsl/simulation/simulator.py", line 53, in advance_and_stabilise_system
#     return self.advance_and_stabilise(self.system, time)
#   File "../crestdsl/simulation/simulator.py", line 62, in advance_and_stabilise
#     ordered_modifiers = DO.get_entity_modifiers_in_dependency_order(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 110, in get_entity_modifiers_in_dependency_order
#     orig_DG = entity_modifier_graph(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 45, in entity_modifier_graph
#     accessed_ports = SH.get_accessed_ports(update.function, update)
#   File "../crestdsl/sourcehelper.py", line 242, in get_accessed_ports
#     ast_body = get_ast_body(function)
#   File "../crestdsl/sourcehelper.py", line 17, in get_ast_body
#     return get_ast_body_from_function_definition(function_or_lambda, rewrite_if_else)
#   File "../crestdsl/sourcehelper.py", line 61, in get_ast_body_from_function_definition
#     return get_ast_from_function_definition(function, rewrite_if_else=rewrite_if_else).body
#   File "../crestdsl/sourcehelper.py", line 30, in get_ast_from_function_definition
#     module = getast(function)
#   File "../crestdsl/sourcehelper.py", line 104, in getast
#     func_ast = ast.parse(getsource(function))
#   File "../crestdsl/sourcehelper.py", line 125, in getsource
#     sl = inspect.getsourcelines(function)
#   File "/opt/conda/lib/python3.7/inspect.py", line 955, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/conda/lib/python3.7/inspect.py", line 828, in findsource
#     if pat.match(lines[lnum]): break
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_presence_produces_correct_lighting_setting (OfficeAutomation.structure.FloorTest) (hw_presence='detected', o1_presence='no presence', o2_presence='no presence', o3_presence='no presence', expected_hallway='on', expected_office1='off', expected_office2='off', expected_office3='off')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "../OfficeAutomation/structure.ipynb", line 1065, in test_presence_produces_correct_lighting_setting
#   File "../crestdsl/simulation/simulator.py", line 45, in stabilise
#     return self.advance_and_stabilise_system(0)
#   File "../crestdsl/simulation/simulator.py", line 53, in advance_and_stabilise_system
#     return self.advance_and_stabilise(self.system, time)
#   File "../crestdsl/simulation/simulator.py", line 62, in advance_and_stabilise
#     ordered_modifiers = DO.get_entity_modifiers_in_dependency_order(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 110, in get_entity_modifiers_in_dependency_order
#     orig_DG = entity_modifier_graph(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 45, in entity_modifier_graph
#     accessed_ports = SH.get_accessed_ports(update.function, update)
#   File "../crestdsl/sourcehelper.py", line 242, in get_accessed_ports
#     ast_body = get_ast_body(function)
#   File "../crestdsl/sourcehelper.py", line 17, in get_ast_body
#     return get_ast_body_from_function_definition(function_or_lambda, rewrite_if_else)
#   File "../crestdsl/sourcehelper.py", line 61, in get_ast_body_from_function_definition
#     return get_ast_from_function_definition(function, rewrite_if_else=rewrite_if_else).body
#   File "../crestdsl/sourcehelper.py", line 30, in get_ast_from_function_definition
#     module = getast(function)
#   File "../crestdsl/sourcehelper.py", line 104, in getast
#     func_ast = ast.parse(getsource(function))
#   File "../crestdsl/sourcehelper.py", line 125, in getsource
#     sl = inspect.getsourcelines(function)
#   File "/opt/conda/lib/python3.7/inspect.py", line 955, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/conda/lib/python3.7/inspect.py", line 828, in findsource
#     if pat.match(lines[lnum]): break
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_presence_produces_correct_lighting_setting (OfficeAutomation.structure.FloorTest) (hw_presence='no presence', o1_presence='detected', o2_presence='no presence', o3_presence='no presence', expected_hallway='on', expected_office1='on', expected_office2='off', expected_office3='off')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "../OfficeAutomation/structure.ipynb", line 1065, in test_presence_produces_correct_lighting_setting
#   File "../crestdsl/simulation/simulator.py", line 45, in stabilise
#     return self.advance_and_stabilise_system(0)
#   File "../crestdsl/simulation/simulator.py", line 53, in advance_and_stabilise_system
#     return self.advance_and_stabilise(self.system, time)
#   File "../crestdsl/simulation/simulator.py", line 62, in advance_and_stabilise
#     ordered_modifiers = DO.get_entity_modifiers_in_dependency_order(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 110, in get_entity_modifiers_in_dependency_order
#     orig_DG = entity_modifier_graph(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 45, in entity_modifier_graph
#     accessed_ports = SH.get_accessed_ports(update.function, update)
#   File "../crestdsl/sourcehelper.py", line 242, in get_accessed_ports
#     ast_body = get_ast_body(function)
#   File "../crestdsl/sourcehelper.py", line 17, in get_ast_body
#     return get_ast_body_from_function_definition(function_or_lambda, rewrite_if_else)
#   File "../crestdsl/sourcehelper.py", line 61, in get_ast_body_from_function_definition
#     return get_ast_from_function_definition(function, rewrite_if_else=rewrite_if_else).body
#   File "../crestdsl/sourcehelper.py", line 30, in get_ast_from_function_definition
#     module = getast(function)
#   File "../crestdsl/sourcehelper.py", line 104, in getast
#     func_ast = ast.parse(getsource(function))
#   File "../crestdsl/sourcehelper.py", line 125, in getsource
#     sl = inspect.getsourcelines(function)
#   File "/opt/conda/lib/python3.7/inspect.py", line 955, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/conda/lib/python3.7/inspect.py", line 828, in findsource
#     if pat.match(lines[lnum]): break
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_presence_produces_correct_lighting_setting (OfficeAutomation.structure.FloorTest) (hw_presence='no presence', o1_presence='no presence', o2_presence='detected', o3_presence='no presence', expected_hallway='on', expected_office1='off', expected_office2='on', expected_office3='off')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "../OfficeAutomation/structure.ipynb", line 1065, in test_presence_produces_correct_lighting_setting
#   File "../crestdsl/simulation/simulator.py", line 45, in stabilise
#     return self.advance_and_stabilise_system(0)
#   File "../crestdsl/simulation/simulator.py", line 53, in advance_and_stabilise_system
#     return self.advance_and_stabilise(self.system, time)
#   File "../crestdsl/simulation/simulator.py", line 62, in advance_and_stabilise
#     ordered_modifiers = DO.get_entity_modifiers_in_dependency_order(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 110, in get_entity_modifiers_in_dependency_order
#     orig_DG = entity_modifier_graph(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 45, in entity_modifier_graph
#     accessed_ports = SH.get_accessed_ports(update.function, update)
#   File "../crestdsl/sourcehelper.py", line 242, in get_accessed_ports
#     ast_body = get_ast_body(function)
#   File "../crestdsl/sourcehelper.py", line 17, in get_ast_body
#     return get_ast_body_from_function_definition(function_or_lambda, rewrite_if_else)
#   File "../crestdsl/sourcehelper.py", line 61, in get_ast_body_from_function_definition
#     return get_ast_from_function_definition(function, rewrite_if_else=rewrite_if_else).body
#   File "../crestdsl/sourcehelper.py", line 30, in get_ast_from_function_definition
#     module = getast(function)
#   File "../crestdsl/sourcehelper.py", line 104, in getast
#     func_ast = ast.parse(getsource(function))
#   File "../crestdsl/sourcehelper.py", line 125, in getsource
#     sl = inspect.getsourcelines(function)
#   File "/opt/conda/lib/python3.7/inspect.py", line 955, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/conda/lib/python3.7/inspect.py", line 828, in findsource
#     if pat.match(lines[lnum]): break
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_presence_produces_correct_lighting_setting (OfficeAutomation.structure.FloorTest) (hw_presence='no presence', o1_presence='no presence', o2_presence='no presence', o3_presence='detected', expected_hallway='on', expected_office1='off', expected_office2='off', expected_office3='on')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "../OfficeAutomation/structure.ipynb", line 1065, in test_presence_produces_correct_lighting_setting
#   File "../crestdsl/simulation/simulator.py", line 45, in stabilise
#     return self.advance_and_stabilise_system(0)
#   File "../crestdsl/simulation/simulator.py", line 53, in advance_and_stabilise_system
#     return self.advance_and_stabilise(self.system, time)
#   File "../crestdsl/simulation/simulator.py", line 62, in advance_and_stabilise
#     ordered_modifiers = DO.get_entity_modifiers_in_dependency_order(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 110, in get_entity_modifiers_in_dependency_order
#     orig_DG = entity_modifier_graph(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 45, in entity_modifier_graph
#     accessed_ports = SH.get_accessed_ports(update.function, update)
#   File "../crestdsl/sourcehelper.py", line 242, in get_accessed_ports
#     ast_body = get_ast_body(function)
#   File "../crestdsl/sourcehelper.py", line 17, in get_ast_body
#     return get_ast_body_from_function_definition(function_or_lambda, rewrite_if_else)
#   File "../crestdsl/sourcehelper.py", line 61, in get_ast_body_from_function_definition
#     return get_ast_from_function_definition(function, rewrite_if_else=rewrite_if_else).body
#   File "../crestdsl/sourcehelper.py", line 30, in get_ast_from_function_definition
#     module = getast(function)
#   File "../crestdsl/sourcehelper.py", line 104, in getast
#     func_ast = ast.parse(getsource(function))
#   File "../crestdsl/sourcehelper.py", line 125, in getsource
#     sl = inspect.getsourcelines(function)
#   File "/opt/conda/lib/python3.7/inspect.py", line 955, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/conda/lib/python3.7/inspect.py", line 828, in findsource
#     if pat.match(lines[lnum]): break
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_too_much_power_drawn (OfficeAutomation.structure.FloorTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "../OfficeAutomation/structure.ipynb", line 1090, in test_too_much_power_drawn
#   File "../crestdsl/simulation/simulator.py", line 45, in stabilise
#     return self.advance_and_stabilise_system(0)
#   File "../crestdsl/simulation/simulator.py", line 53, in advance_and_stabilise_system
#     return self.advance_and_stabilise(self.system, time)
#   File "../crestdsl/simulation/simulator.py", line 62, in advance_and_stabilise
#     ordered_modifiers = DO.get_entity_modifiers_in_dependency_order(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 110, in get_entity_modifiers_in_dependency_order
#     orig_DG = entity_modifier_graph(entity)
#   File "../crestdsl/simulation/dependencyOrder.py", line 45, in entity_modifier_graph
#     accessed_ports = SH.get_accessed_ports(update.function, update)
#   File "../crestdsl/sourcehelper.py", line 242, in get_accessed_ports
#     ast_body = get_ast_body(function)
#   File "../crestdsl/sourcehelper.py", line 17, in get_ast_body
#     return get_ast_body_from_function_definition(function_or_lambda, rewrite_if_else)
#   File "../crestdsl/sourcehelper.py", line 61, in get_ast_body_from_function_definition
#     return get_ast_from_function_definition(function, rewrite_if_else=rewrite_if_else).body
#   File "../crestdsl/sourcehelper.py", line 30, in get_ast_from_function_definition
#     module = getast(function)
#   File "../crestdsl/sourcehelper.py", line 104, in getast
#     func_ast = ast.parse(getsource(function))
#   File "../crestdsl/sourcehelper.py", line 125, in getsource
#     sl = inspect.getsourcelines(function)
#   File "/opt/conda/lib/python3.7/inspect.py", line 955, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/opt/conda/lib/python3.7/inspect.py", line 828, in findsource
#     if pat.match(lines[lnum]): break
# IndexError: list index out of range
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.317s
#
# FAILED (errors=6)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/CREST/crestdsl/ui/elk.py in gen_Update(obj, name, parent, **kwargs)
#     222         # try:
# --> 223         sourcecode = SH.getsource(obj.function).replace('"', '\"')
#     224         # except:
#
# ~/CREST/crestdsl/sourcehelper.py in getsource(function)
#     124
# --> 125     sl = inspect.getsourcelines(function)
#     126     sourcelines = sl[0]
#
# /opt/conda/lib/python3.7/inspect.py in getsourcelines(object)
#     954     object = unwrap(object)
# --> 955     lines, lnum = findsource(object)
#     956
#
# /opt/conda/lib/python3.7/inspect.py in findsource(object)
#     827         while lnum > 0:
# --> 828             if pat.match(lines[lnum]): break
#     829             lnum = lnum - 1
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-93f5c28f69fc> in <module>
#       2 from importnb import Notebook
#       3 with Notebook():
# ----> 4     import OfficeAutomation.structure as structure
#       5     import OfficeAutomation.environment as env
#
# ~/CREST/OfficeAutomation/structure.ipynb in <module>
#
# ~/CREST/crestdsl/ui/__init__.py in plot(object, name)
#       5 def plot(object,  name=''):
#       6     from crestdsl.config import config
# ----> 7     return config.default_plotter.plot(object, name=name)
#
# ~/CREST/crestdsl/ui/elk.py in plot(object_to_plot, name, **kwargs)
#      27
#      28 def plot(object_to_plot, name='', **kwargs):
# ---> 29     elkgraph = generate_root(object_to_plot, name)
#      30     elkgraph = str(elkgraph)
#      31
#
# ~/CREST/crestdsl/ui/elk.py in generate_root(object_to_plot, name)
#      58 def generate_root(object_to_plot, name):
#      59     """ wraps the generated graph in a root entity """
# ---> 60     graph = generate(object_to_plot, name)
#      61     root = {
#      62         'id': 'root',
#
# /opt/conda/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/CREST/crestdsl/ui/elk.py in gen_Entity(obj, name, parent, **kwargs)
#     122
#     123     for name_, update in Model.get_updates(obj, as_dict=True).items():
# --> 124         node["edges"].extend(generate(update, name_, obj, **kwargs))
#     125         pass
#     126
#
# /opt/conda/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/CREST/crestdsl/ui/elk.py in gen_Update(obj, name, parent, **kwargs)
#     237         }]
#     238     except Exception as e:
# --> 239         print(e.message, e.args)
#     240         import pdb; pdb.set_trace()
#     241         pass
#
# AttributeError: 'IndexError' object has no attribute 'message'

# %%
import crestdsl.model as crest
import crestdsl.simulation as crestsim
import crestdsl.ui as ui

# %%
class System(crest.Entity):
    environment = env.Environment()
    floor = structure.Floor()
